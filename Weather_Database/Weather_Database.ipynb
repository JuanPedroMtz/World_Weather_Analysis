# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress
import gmaps

# %%
lat = np.random.uniform(-90, 90, size = 2000)
lon = np.random.uniform(-180, 180, size = 2000)
lats_lons = zip(lat, lon)
coordinates = list(lats_lons)

# %%
from citipy import citipy

# %%
# List to hold cities
cities = []
#    Nearest city 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Looking for unique cities 
    
    if city not in cities:
        cities.append(city)
        
cities
# Out:
# ['nizhneyansk',
#  'port lincoln',
#  'mataura',
#  'san lorenzo',
#  'norman wells',
#  'atagay',
#  'hermanus',
#  'kazachinskoye',
#  'vaini',
#  'puerto ayora',
#  'avarua',
#  'qaqortoq',
#  'coihaique',
#  'lamar',
#  'ushuaia',
#  'kruisfontein',
#  'inderborskiy',
#  'bandarbeyla',
#  'henties bay',
#  'ivanteyevka',
#  'cabo san lucas',
#  'ormara',
#  'jamestown',
#  'gizo',
#  'rikitea',
#  'kapaa',
#  'luena',
#  'busselton',
#  'albany',
#  'paracatu',
#  'dwarka',
#  'touros',
#  'carnarvon',
#  'tocopilla',
#  'hovd',
#  'tsihombe',
#  'thompson',
#  'inhambane',
#  'ratnagiri',
#  'saint george',
#  'yellowknife',
#  'bluff',
#  'mamakan',
#  'turukhansk',
#  'gdansk',
#  'ixtapa',
#  'castro',
#  'denpasar',
#  'kidal',
#  'pisco',
#  'kapit',
#  'guerrero negro',
#  'ucluelet',
#  'barcelos',
#  'chikoy',
#  'rybnoye',
#  'mar del plata',
#  'vacaria',
#  'sao jose da coroa grande',
#  'fortuna',
#  'husavik',
#  'butaritari',
#  'illapel',
#  'saskylakh',
#  'marystown',
#  'sola',
#  'alindao',
#  'beatrice',
#  'georgetown',
#  'san cristobal',
#  'raudeberg',
#  'techiman',
#  'birsk',
#  'provideniya',
#  'qaanaaq',
#  'atar',
#  'hithadhoo',
#  'evensk',
#  'hohhot',
#  'barrow',
#  'mandalgovi',
#  'ostrovnoy',
#  'naryan-mar',
#  'illoqqortoormiut',
#  'launceston',
#  'giyon',
#  'lata',
#  'souillac',
#  'hilo',
#  'logan',
#  'humberto de campos',
#  'longlac',
#  'bengkulu',
#  'hobart',
#  'jiblah',
#  'luderitz',
#  'andenes',
#  'tripoli',
#  'clyde river',
#  'toliary',
#  'takoradi',
#  'tasiilaq',
#  'samarai',
#  'mitu',
#  'ancud',
#  'valparaiso',
#  'yulara',
#  'haines junction',
#  'atuona',
#  'los llanos de aridane',
#  'belushya guba',
#  'arraial do cabo',
#  'antofagasta',
#  'port elizabeth',
#  'kashiba',
#  'longyearbyen',
#  'margate',
#  'asyut',
#  'naze',
#  'tomatlan',
#  'bethel',
#  'muros',
#  'vostok',
#  'havre-saint-pierre',
#  'manicore',
#  'snasa',
#  'ribeira grande',
#  'lucapa',
#  'chuy',
#  'seydisehir',
#  'hasaki',
#  'kodiak',
#  'hamilton',
#  'saint-philippe',
#  'yei',
#  'anadyr',
#  'lompoc',
#  'myanaung',
#  'marcona',
#  'new norfolk',
#  'cape town',
#  'lebu',
#  'cidreira',
#  'port hedland',
#  'punta arenas',
#  'saint anthony',
#  'nikolskoye',
#  'australind',
#  'cordoba',
#  'surt',
#  'antalaha',
#  'bobo dioulasso',
#  'simacota',
#  'taolanaro',
#  'bredasdorp',
#  'faanui',
#  'palaikastron',
#  'vaitape',
#  'dikson',
#  'veraval',
#  'hambantota',
#  'chor',
#  'pevek',
#  'umzimvubu',
#  'ponta do sol',
#  'havelock',
#  'halalo',
#  'daru',
#  'tiksi',
#  'namatanai',
#  'ambulu',
#  'puerto escondido',
#  'tabiauea',
#  'sentyabrskiy',
#  'wooster',
#  'troitskoye',
#  'dunedin',
#  'ayr',
#  'oistins',
#  'tevriz',
#  'codrington',
#  'aklavik',
#  'hollins',
#  'padang',
#  'thabazimbi',
#  'gloucester',
#  'bad liebenwerda',
#  'shahrud',
#  'trelew',
#  'tecoanapa',
#  'aliwal north',
#  'flinders',
#  'caucaia',
#  'adwa',
#  'kachug',
#  'kropotkin',
#  'beder',
#  'chokurdakh',
#  'jumla',
#  'chagda',
#  'port alfred',
#  'zhanaozen',
#  'dolores',
#  'lagoa',
#  'olafsvik',
#  'burriana',
#  'cherskiy',
#  'solnechnyy',
#  'kashi',
#  'palana',
#  'kawana waters',
#  'todos santos',
#  'balclutha',
#  'boende',
#  'muisne',
#  'san quintin',
#  'killybegs',
#  'baykit',
#  'gura teghii',
#  'pavlovka',
#  'torbay',
#  'mys shmidta',
#  'dicabisagan',
#  'narsaq',
#  'marawi',
#  'glens falls',
#  'komsomolskiy',
#  'victoria',
#  'east london',
#  'lavrentiya',
#  'santa isabel do rio negro',
#  'airai',
#  'napoleon',
#  'shelburne',
#  'katsuura',
#  'vilhena',
#  'deh rawud',
#  'simbahan',
#  'vardo',
#  'dudinka',
#  'hofn',
#  'tuktoyaktuk',
#  'adrar',
#  'beyneu',
#  'gobabis',
#  'kalabo',
#  'tartagal',
#  'lorengau',
#  'danilovka',
#  'uaua',
#  'faya',
#  'adjumani',
#  'attawapiskat',
#  'voznesenye',
#  'grindavik',
#  'alghero',
#  'barentsburg',
#  'shugurovo',
#  'mahebourg',
#  'port macquarie',
#  'saleaula',
#  'tuatapere',
#  'rio brilhante',
#  'severo-kurilsk',
#  'upernavik',
#  'farafangana',
#  'ketchikan',
#  'morehead',
#  'achacachi',
#  'nanortalik',
#  'khandyga',
#  'ahumada',
#  'gazojak',
#  'paraiba do sul',
#  'jalu',
#  'karaul',
#  'hami',
#  'altamont',
#  'pamanukan',
#  'hlobyne',
#  'umm lajj',
#  'ust-kamchatsk',
#  'bilibino',
#  'laguna',
#  'balykshi',
#  'umm kaddadah',
#  'notre-dame-du-lac',
#  'koltubanovskiy',
#  'gisborne',
#  'thinadhoo',
#  'mount gambier',
#  'lolua',
#  'lingyuan',
#  'whitehorse',
#  'matadi',
#  'meulaboh',
#  'talnakh',
#  'luanda',
#  'ust-maya',
#  'mehamn',
#  'maningrida',
#  'namibe',
#  'usak',
#  'ulaangom',
#  'comodoro rivadavia',
#  'cabudare',
#  'lovington',
#  'sao goncalo dos campos',
#  'vidisha',
#  'churapcha',
#  'karratha',
#  'broome',
#  'sorland',
#  'tumannyy',
#  'qandala',
#  'cockburn town',
#  'kushiro',
#  'salinopolis',
#  'matagami',
#  'sosnovo-ozerskoye',
#  'tezu',
#  'kargala',
#  'kenai',
#  'vasteras',
#  'galgani',
#  'valley city',
#  'amderma',
#  'nyurba',
#  'vilcun',
#  'nenjiang',
#  'verkhoyansk',
#  'gushikawa',
#  'aykhal',
#  'the valley',
#  'high rock',
#  'khatanga',
#  'kuche',
#  'igarka',
#  'ranong',
#  'hefei',
#  'mayo',
#  'kouqian',
#  'hwange',
#  'kayerkan',
#  'araouane',
#  'nantucket',
#  'kavieng',
#  'bilma',
#  'ende',
#  'lubben',
#  'paulo afonso',
#  'bolungarvik',
#  'atasu',
#  'banes',
#  'boa vista',
#  'burnie',
#  'dingle',
#  'vaitupu',
#  'masoko',
#  'soddy-daisy',
#  'oranjemund',
#  'skjervoy',
#  'mkushi',
#  'saldanha',
#  'erdenet',
#  'ozieri',
#  'selma',
#  'parkes',
#  'mount isa',
#  'lima duarte',
#  'severobaykalsk',
#  'haapiti',
#  'goma',
#  'novobirilyussy',
#  'oranjestad',
#  'virginia beach',
#  'yuzhno-kurilsk',
#  'cururupu',
#  'shimodate',
#  'miguel alves',
#  'presidencia roque saenz pena',
#  'inongo',
#  'gastonia',
#  'saint-pierre',
#  'artyk',
#  'saint-ambroise',
#  'coquimbo',
#  'kahului',
#  'kirensk',
#  'labuhan',
#  'tiznit',
#  'camacha',
#  'salalah',
#  'arman',
#  'naqadeh',
#  'dzhusaly',
#  'aleksandrov gay',
#  'koumac',
#  'kemijarvi',
#  'georgiyevka',
#  'port blair',
#  'kirakira',
#  'angoram',
#  'hobyo',
#  'carahue',
#  'samusu',
#  'ewa beach',
#  'catio',
#  'saint-augustin',
#  'jiuquan',
#  'wajid',
#  'voyvozh',
#  'acarau',
#  'imbituba',
#  'tilichiki',
#  'maragogi',
#  'bemidji',
#  'louisbourg',
#  'mangrol',
#  'svetlogorsk',
#  'codajas',
#  'itarema',
#  'merauke',
#  'melipilla',
#  'kuito',
#  'teknaf',
#  'noumea',
#  'abu kamal',
#  'staryy nadym',
#  'termoli',
#  'iqaluit',
#  'kaduna',
#  'garissa',
#  'ushtobe',
#  'soyo',
#  'baruun-urt',
#  'terrace',
#  'ust-nera',
#  'esperance',
#  'yarada',
#  'kimbe',
#  'franklin',
#  'itapetinga',
#  'belyy',
#  'latehar',
#  'isla mujeres',
#  'socorro',
#  'wyszkow',
#  'ambilobe',
#  'yen bai',
#  'grand gaube',
#  'praia da vitoria',
#  'colesberg',
#  'ampanihy',
#  'beringovskiy',
#  'filadelfia',
#  'leo',
#  'whitefish',
#  'berlevag',
#  'ulladulla',
#  'ilulissat',
#  'guarapari',
#  'gold coast',
#  'iida',
#  'tawzar',
#  'bahile',
#  'assemini',
#  'waterfoot',
#  'zhigansk',
#  'isiro',
#  'joensuu',
#  'pacific grove',
#  'paracuru',
#  'axim',
#  'dondo',
#  'sungaipenuh',
#  'anori',
#  'wanning',
#  'saucillo',
#  'sitka',
#  'goderich',
#  'porlamar',
#  'fare',
#  'yumen',
#  'alta floresta',
#  'nizwa',
#  'vestmanna',
#  'jimenez',
#  'palabuhanratu',
#  'kavaratti',
#  'verkhnyaya inta',
#  'yaan',
#  'doka',
#  'balkhash',
#  'disna',
#  'bolgar',
#  'vuktyl',
#  'rundu',
#  'silifke',
#  'isangel',
#  'monrovia',
#  'gavle',
#  'kamaishi',
#  'alofi',
#  'phan rang',
#  'matamoros',
#  'yeppoon',
#  'vicuna',
#  'caravelas',
#  'redmond',
#  'mafinga',
#  'syracuse',
#  'baiima',
#  'shubarshi',
#  'taywarah',
#  'kirkenaer',
#  'abu samrah',
#  'natal',
#  'bosaso',
#  'arlit',
#  'san martin de hidalgo',
#  'san patricio',
#  'bogorodskoye',
#  'cherepovets',
#  'biltine',
#  'nakhon thai',
#  'kalaleh',
#  'manokwari',
#  'mawlaik',
#  'ust-omchug',
#  'rio grande',
#  'lannion',
#  'kathmandu',
#  'chinu',
#  'bayangol',
#  'rustenburg',
#  'half moon bay',
#  'kaitangata',
#  'ejea de los caballeros',
#  'chifeng',
#  'nizhniy tsasuchey',
#  'minab',
#  'kontagora',
#  'mata grande',
#  'casper',
#  'lasa',
#  'nome',
#  'klaksvik',
#  'kalmunai',
#  'san jeronimo',
#  'oktyabrskoye',
#  'nouakchott',
#  'vilyuysk',
#  'bowen',
#  'nhulunbuy',
#  'ghansor',
#  'longhua',
#  'sioux lookout',
#  'ayaviri',
#  'mikuni',
#  'nemuro',
#  'sobolevo',
#  'zeya',
#  'eyl',
#  'mingaora',
#  'sibolga',
#  'broken hill',
#  'novosergiyevka',
#  'liminangcong',
#  'martapura',
#  'shangrao',
#  'woodstock',
#  'jaypur',
#  'tatarskaya pishlya',
#  'conde',
#  'hundorp',
#  'cayenne',
#  'puerto ayacucho',
#  'orlik',
#  'tandalti',
#  'lindas',
#  'whitianga',
#  'srednekolymsk',
#  'te anau',
#  'bektemir',
#  'kinkala',
#  'aguilas',
#  'temaraia',
#  'farah',
#  'jericho',
#  'manzhouli',
#  'sangar',
#  'rognan',
#  'bazarnyy syzgan',
#  'high level',
#  'vila velha',
#  'banbury',
#  'muzaffarabad',
#  'lovozero',
#  'winneba',
#  'aguas formosas',
#  'san ramon',
#  'general roca',
#  'shitkino',
#  'roma',
#  'talavera de la reina',
#  'toamasina',
#  'waingapu',
#  'labuan',
#  'sawakin',
#  'hailar',
#  'salamanca',
#  'kharp',
#  'opuwo',
#  'vanavara',
#  'pedasi',
#  'kano',
#  'zabol',
#  'gayeri',
#  'san gabriel',
#  'dawlatabad',
#  'mananjary',
#  'vila franca do campo',
#  'zyryanka',
#  'les cayes',
#  'himora',
#  'jacqueville',
#  'iguguno',
#  'cuenca',
#  'biscarrosse',
#  'sept-iles',
#  'bengbu',
#  'sinnamary',
#  'hinton',
#  'gorin',
#  'mentougou',
#  'tommot',
#  'lalmohan',
#  'rungata',
#  'samarinda',
#  'tupik',
#  'satitoa',
#  'macas',
#  'nuuk',
#  'nishihara',
#  'buchanan',
#  'severnoye',
#  'palaia fokaia',
#  'jiddah',
#  'soubre',
#  'bubaque',
#  'hay river',
#  'kombissiri',
#  'lazaro cardenas',
#  'auki',
#  'asfi',
#  'cubara',
#  'pavlogradka',
#  'forbes',
#  'la palma',
#  'neutraubling',
#  'general teran',
#  'yueyang',
#  'pangnirtung',
#  'roebourne',
#  'amazar',
#  'nalut',
#  'zanjan',
#  'laurel',
#  'kijang',
#  'vanino',
#  'mocuba',
#  'aksu',
#  'sao filipe',
#  'khatra',
#  'roald',
#  'slavyanka',
#  'santa rosa',
#  'egvekinot',
#  'nizhneudinsk',
#  'port arthur',
#  'hualmay',
#  'pakenham',
#  'champerico',
#  'dolgoprudnyy',
#  'gorkovskoye',
#  'jacmel',
#  'norrtalje',
#  'asau',
#  'morant bay',
#  'shache',
#  'janauba',
#  'banjar',
#  'anarcs',
#  'vogar',
#  'walvis bay',
#  'pitea',
#  'vagay',
#  'anisoc',
#  'jijiga',
#  'lethem',
#  'luancheng',
#  'imeni babushkina',
#  'valky',
#  'uyemskiy',
#  'yingkou',
#  'rochegda',
#  'aswan',
#  'lianran',
#  'marfino',
#  'inirida',
#  'vangaindrano',
#  'kitzingen',
#  'atamanskaya',
#  'ahipara',
#  'harper',
#  'riyadh',
#  'kot putli',
#  'rabo de peixe',
#  'santiago de compostela',
#  'caohe',
#  'braniewo',
#  'ulkan',
#  'golden',
#  'manta',
#  'paka',
#  'skalistyy',
#  'ouallam',
#  'college',
#  'omsukchan',
#  'pahrump',
#  'bambous virieux',
#  'qui nhon',
#  'stepnyak',
#  'zhuhai',
#  'conceicao da barra',
#  'wahran',
#  'fairbanks',
#  'ribas do rio pardo',
#  'gao',
#  'ghanzi',
#  'dabakala',
#  'kindu',
#  'sao joao da barra',
#  'teahupoo',
#  'maloshuyka',
#  'gambela',
#  'bolshegrivskoye',
#  'damietta',
#  'tambopata',
#  'chadiza',
#  'langxiang',
#  'birao',
#  'kholodnyy',
#  'kununurra',
#  'maple creek',
#  'charters towers']

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time
from datetime import datetime

# %%
# List to hold data 
city_data = []
print("Beginning Data Retrieval   ")
print("---------------------------")

record_count = 1 
set_count = 1 

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(30)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try: 
        city_weather = requests.get(city_url).json()
        city = city_weather["name"]
        country = city_weather["sys"]["country"]
        date = city_weather["dt"]
        datetime.utcfromtimestamp(date).strftime("%Y-%m-%d %H:%M:%S")
        lon = city_weather["coord"]["lon"]
        lat = city_weather["coord"]["lat"]
        temp_max = city_weather["main"]["temp_max"]
        temp_min = city_weather["main"]["temp_min"]
        humidity = city_weather["main"]["humidity"]
        cloudiness = city_weather["clouds"]["all"]
        wind_speed = city_weather["wind"]["speed"]
        description = city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                              "Lat": lat,
                              "Lng": lon,
                              "Max Temp": temp_max,
                              "Humidity": humidity,
                              "Cloudiness": cloudiness,
                              "Wind Speed": wind_speed,
                              "Country": country,
                              "Description": description,
                              "Date": date})
    except(KeyError): 
        print("City not found. Skipping...")
        pass 

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 1 | port lincoln
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | san lorenzo
# Processing Record 5 of Set 1 | norman wells
# Processing Record 6 of Set 1 | atagay
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | kazachinskoye
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | qaqortoq
# Processing Record 13 of Set 1 | coihaique
# Processing Record 14 of Set 1 | lamar
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | kruisfontein
# Processing Record 17 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 18 of Set 1 | bandarbeyla
# Processing Record 19 of Set 1 | henties bay
# Processing Record 20 of Set 1 | ivanteyevka
# Processing Record 21 of Set 1 | cabo san lucas
# Processing Record 22 of Set 1 | ormara
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | gizo
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | luena
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | paracatu
# Processing Record 31 of Set 1 | dwarka
# Processing Record 32 of Set 1 | touros
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | tocopilla
# Processing Record 35 of Set 1 | hovd
# Processing Record 36 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | inhambane
# Processing Record 39 of Set 1 | ratnagiri
# Processing Record 40 of Set 1 | saint george
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | mamakan
# Processing Record 44 of Set 1 | turukhansk
# Processing Record 45 of Set 1 | gdansk
# Processing Record 46 of Set 1 | ixtapa
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | denpasar
# Processing Record 49 of Set 1 | kidal
# Processing Record 50 of Set 1 | pisco
# Processing Record 1 of Set 2 | kapit
# Processing Record 2 of Set 2 | guerrero negro
# Processing Record 3 of Set 2 | ucluelet
# Processing Record 4 of Set 2 | barcelos
# Processing Record 5 of Set 2 | chikoy
# City not found. Skipping...
# Processing Record 6 of Set 2 | rybnoye
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | vacaria
# Processing Record 9 of Set 2 | sao jose da coroa grande
# Processing Record 10 of Set 2 | fortuna
# Processing Record 11 of Set 2 | husavik
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | illapel
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | marystown
# Processing Record 16 of Set 2 | sola
# Processing Record 17 of Set 2 | alindao
# Processing Record 18 of Set 2 | beatrice
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | san cristobal
# Processing Record 21 of Set 2 | raudeberg
# Processing Record 22 of Set 2 | techiman
# Processing Record 23 of Set 2 | birsk
# Processing Record 24 of Set 2 | provideniya
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | atar
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | evensk
# Processing Record 29 of Set 2 | hohhot
# Processing Record 30 of Set 2 | barrow
# Processing Record 31 of Set 2 | mandalgovi
# Processing Record 32 of Set 2 | ostrovnoy
# Processing Record 33 of Set 2 | naryan-mar
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | launceston
# Processing Record 36 of Set 2 | giyon
# Processing Record 37 of Set 2 | lata
# Processing Record 38 of Set 2 | souillac
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | logan
# Processing Record 41 of Set 2 | humberto de campos
# Processing Record 42 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 43 of Set 2 | bengkulu
# Processing Record 44 of Set 2 | hobart
# Processing Record 45 of Set 2 | jiblah
# Processing Record 46 of Set 2 | luderitz
# Processing Record 47 of Set 2 | andenes
# Processing Record 48 of Set 2 | tripoli
# Processing Record 49 of Set 2 | clyde river
# Processing Record 50 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 3 | takoradi
# Processing Record 2 of Set 3 | tasiilaq
# Processing Record 3 of Set 3 | samarai
# Processing Record 4 of Set 3 | mitu
# Processing Record 5 of Set 3 | ancud
# Processing Record 6 of Set 3 | valparaiso
# Processing Record 7 of Set 3 | yulara
# Processing Record 8 of Set 3 | haines junction
# Processing Record 9 of Set 3 | atuona
# Processing Record 10 of Set 3 | los llanos de aridane
# Processing Record 11 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | antofagasta
# Processing Record 14 of Set 3 | port elizabeth
# Processing Record 15 of Set 3 | kashiba
# Processing Record 16 of Set 3 | longyearbyen
# Processing Record 17 of Set 3 | margate
# Processing Record 18 of Set 3 | asyut
# Processing Record 19 of Set 3 | naze
# Processing Record 20 of Set 3 | tomatlan
# Processing Record 21 of Set 3 | bethel
# Processing Record 22 of Set 3 | muros
# Processing Record 23 of Set 3 | vostok
# Processing Record 24 of Set 3 | havre-saint-pierre
# Processing Record 25 of Set 3 | manicore
# Processing Record 26 of Set 3 | snasa
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | lucapa
# Processing Record 29 of Set 3 | chuy
# Processing Record 30 of Set 3 | seydisehir
# Processing Record 31 of Set 3 | hasaki
# Processing Record 32 of Set 3 | kodiak
# Processing Record 33 of Set 3 | hamilton
# Processing Record 34 of Set 3 | saint-philippe
# Processing Record 35 of Set 3 | yei
# Processing Record 36 of Set 3 | anadyr
# Processing Record 37 of Set 3 | lompoc
# Processing Record 38 of Set 3 | myanaung
# Processing Record 39 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 3 | new norfolk
# Processing Record 41 of Set 3 | cape town
# Processing Record 42 of Set 3 | lebu
# Processing Record 43 of Set 3 | cidreira
# Processing Record 44 of Set 3 | port hedland
# Processing Record 45 of Set 3 | punta arenas
# Processing Record 46 of Set 3 | saint anthony
# Processing Record 47 of Set 3 | nikolskoye
# Processing Record 48 of Set 3 | australind
# Processing Record 49 of Set 3 | cordoba
# Processing Record 50 of Set 3 | surt
# Processing Record 1 of Set 4 | antalaha
# Processing Record 2 of Set 4 | bobo dioulasso
# Processing Record 3 of Set 4 | simacota
# Processing Record 4 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 4 | bredasdorp
# Processing Record 6 of Set 4 | faanui
# Processing Record 7 of Set 4 | palaikastron
# Processing Record 8 of Set 4 | vaitape
# Processing Record 9 of Set 4 | dikson
# Processing Record 10 of Set 4 | veraval
# Processing Record 11 of Set 4 | hambantota
# Processing Record 12 of Set 4 | chor
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 4 | ponta do sol
# Processing Record 16 of Set 4 | havelock
# Processing Record 17 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 18 of Set 4 | daru
# Processing Record 19 of Set 4 | tiksi
# Processing Record 20 of Set 4 | namatanai
# Processing Record 21 of Set 4 | ambulu
# Processing Record 22 of Set 4 | puerto escondido
# Processing Record 23 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 4 | wooster
# Processing Record 26 of Set 4 | troitskoye
# Processing Record 27 of Set 4 | dunedin
# Processing Record 28 of Set 4 | ayr
# Processing Record 29 of Set 4 | oistins
# Processing Record 30 of Set 4 | tevriz
# Processing Record 31 of Set 4 | codrington
# Processing Record 32 of Set 4 | aklavik
# Processing Record 33 of Set 4 | hollins
# Processing Record 34 of Set 4 | padang
# Processing Record 35 of Set 4 | thabazimbi
# Processing Record 36 of Set 4 | gloucester
# Processing Record 37 of Set 4 | bad liebenwerda
# Processing Record 38 of Set 4 | shahrud
# Processing Record 39 of Set 4 | trelew
# Processing Record 40 of Set 4 | tecoanapa
# Processing Record 41 of Set 4 | aliwal north
# Processing Record 42 of Set 4 | flinders
# Processing Record 43 of Set 4 | caucaia
# Processing Record 44 of Set 4 | adwa
# Processing Record 45 of Set 4 | kachug
# Processing Record 46 of Set 4 | kropotkin
# Processing Record 47 of Set 4 | beder
# Processing Record 48 of Set 4 | chokurdakh
# Processing Record 49 of Set 4 | jumla
# Processing Record 50 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 5 | port alfred
# Processing Record 2 of Set 5 | zhanaozen
# Processing Record 3 of Set 5 | dolores
# Processing Record 4 of Set 5 | lagoa
# Processing Record 5 of Set 5 | olafsvik
# Processing Record 6 of Set 5 | burriana
# Processing Record 7 of Set 5 | cherskiy
# Processing Record 8 of Set 5 | solnechnyy
# Processing Record 9 of Set 5 | kashi
# Processing Record 10 of Set 5 | palana
# Processing Record 11 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 12 of Set 5 | todos santos
# Processing Record 13 of Set 5 | balclutha
# Processing Record 14 of Set 5 | boende
# Processing Record 15 of Set 5 | muisne
# Processing Record 16 of Set 5 | san quintin
# Processing Record 17 of Set 5 | killybegs
# Processing Record 18 of Set 5 | baykit
# Processing Record 19 of Set 5 | gura teghii
# Processing Record 20 of Set 5 | pavlovka
# Processing Record 21 of Set 5 | torbay
# Processing Record 22 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 5 | dicabisagan
# Processing Record 24 of Set 5 | narsaq
# Processing Record 25 of Set 5 | marawi
# Processing Record 26 of Set 5 | glens falls
# Processing Record 27 of Set 5 | komsomolskiy
# Processing Record 28 of Set 5 | victoria
# Processing Record 29 of Set 5 | east london
# Processing Record 30 of Set 5 | lavrentiya
# Processing Record 31 of Set 5 | santa isabel do rio negro
# Processing Record 32 of Set 5 | airai
# Processing Record 33 of Set 5 | napoleon
# Processing Record 34 of Set 5 | shelburne
# Processing Record 35 of Set 5 | katsuura
# Processing Record 36 of Set 5 | vilhena
# Processing Record 37 of Set 5 | deh rawud
# City not found. Skipping...
# Processing Record 38 of Set 5 | simbahan
# Processing Record 39 of Set 5 | vardo
# Processing Record 40 of Set 5 | dudinka
# Processing Record 41 of Set 5 | hofn
# Processing Record 42 of Set 5 | tuktoyaktuk
# Processing Record 43 of Set 5 | adrar
# Processing Record 44 of Set 5 | beyneu
# Processing Record 45 of Set 5 | gobabis
# Processing Record 46 of Set 5 | kalabo
# Processing Record 47 of Set 5 | tartagal
# Processing Record 48 of Set 5 | lorengau
# Processing Record 49 of Set 5 | danilovka
# Processing Record 50 of Set 5 | uaua
# Processing Record 1 of Set 6 | faya
# Processing Record 2 of Set 6 | adjumani
# Processing Record 3 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 6 | voznesenye
# Processing Record 5 of Set 6 | grindavik
# Processing Record 6 of Set 6 | alghero
# Processing Record 7 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 6 | shugurovo
# Processing Record 9 of Set 6 | mahebourg
# Processing Record 10 of Set 6 | port macquarie
# Processing Record 11 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 6 | tuatapere
# Processing Record 13 of Set 6 | rio brilhante
# Processing Record 14 of Set 6 | severo-kurilsk
# Processing Record 15 of Set 6 | upernavik
# Processing Record 16 of Set 6 | farafangana
# Processing Record 17 of Set 6 | ketchikan
# Processing Record 18 of Set 6 | morehead
# Processing Record 19 of Set 6 | achacachi
# Processing Record 20 of Set 6 | nanortalik
# Processing Record 21 of Set 6 | khandyga
# Processing Record 22 of Set 6 | ahumada
# City not found. Skipping...
# Processing Record 23 of Set 6 | gazojak
# Processing Record 24 of Set 6 | paraiba do sul
# Processing Record 25 of Set 6 | jalu
# Processing Record 26 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 6 | hami
# Processing Record 28 of Set 6 | altamont
# Processing Record 29 of Set 6 | pamanukan
# Processing Record 30 of Set 6 | hlobyne
# Processing Record 31 of Set 6 | umm lajj
# Processing Record 32 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 6 | bilibino
# Processing Record 34 of Set 6 | laguna
# Processing Record 35 of Set 6 | balykshi
# Processing Record 36 of Set 6 | umm kaddadah
# Processing Record 37 of Set 6 | notre-dame-du-lac
# Processing Record 38 of Set 6 | koltubanovskiy
# Processing Record 39 of Set 6 | gisborne
# Processing Record 40 of Set 6 | thinadhoo
# Processing Record 41 of Set 6 | mount gambier
# Processing Record 42 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 6 | lingyuan
# Processing Record 44 of Set 6 | whitehorse
# Processing Record 45 of Set 6 | matadi
# Processing Record 46 of Set 6 | meulaboh
# Processing Record 47 of Set 6 | talnakh
# Processing Record 48 of Set 6 | luanda
# Processing Record 49 of Set 6 | ust-maya
# Processing Record 50 of Set 6 | mehamn
# Processing Record 1 of Set 7 | maningrida
# Processing Record 2 of Set 7 | namibe
# Processing Record 3 of Set 7 | usak
# Processing Record 4 of Set 7 | ulaangom
# Processing Record 5 of Set 7 | comodoro rivadavia
# Processing Record 6 of Set 7 | cabudare
# Processing Record 7 of Set 7 | lovington
# Processing Record 8 of Set 7 | sao goncalo dos campos
# Processing Record 9 of Set 7 | vidisha
# Processing Record 10 of Set 7 | churapcha
# Processing Record 11 of Set 7 | karratha
# Processing Record 12 of Set 7 | broome
# Processing Record 13 of Set 7 | sorland
# Processing Record 14 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 7 | qandala
# Processing Record 16 of Set 7 | cockburn town
# Processing Record 17 of Set 7 | kushiro
# Processing Record 18 of Set 7 | salinopolis
# Processing Record 19 of Set 7 | matagami
# Processing Record 20 of Set 7 | sosnovo-ozerskoye
# Processing Record 21 of Set 7 | tezu
# Processing Record 22 of Set 7 | kargala
# Processing Record 23 of Set 7 | kenai
# Processing Record 24 of Set 7 | vasteras
# Processing Record 25 of Set 7 | galgani
# City not found. Skipping...
# Processing Record 26 of Set 7 | valley city
# Processing Record 27 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 7 | nyurba
# Processing Record 29 of Set 7 | vilcun
# Processing Record 30 of Set 7 | nenjiang
# Processing Record 31 of Set 7 | verkhoyansk
# Processing Record 32 of Set 7 | gushikawa
# Processing Record 33 of Set 7 | aykhal
# Processing Record 34 of Set 7 | the valley
# Processing Record 35 of Set 7 | high rock
# Processing Record 36 of Set 7 | khatanga
# Processing Record 37 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 7 | igarka
# Processing Record 39 of Set 7 | ranong
# Processing Record 40 of Set 7 | hefei
# Processing Record 41 of Set 7 | mayo
# Processing Record 42 of Set 7 | kouqian
# Processing Record 43 of Set 7 | hwange
# Processing Record 44 of Set 7 | kayerkan
# Processing Record 45 of Set 7 | araouane
# Processing Record 46 of Set 7 | nantucket
# Processing Record 47 of Set 7 | kavieng
# Processing Record 48 of Set 7 | bilma
# Processing Record 49 of Set 7 | ende
# Processing Record 50 of Set 7 | lubben
# Processing Record 1 of Set 8 | paulo afonso
# Processing Record 2 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 8 | atasu
# Processing Record 4 of Set 8 | banes
# Processing Record 5 of Set 8 | boa vista
# Processing Record 6 of Set 8 | burnie
# Processing Record 7 of Set 8 | dingle
# Processing Record 8 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 8 | masoko
# Processing Record 10 of Set 8 | soddy-daisy
# Processing Record 11 of Set 8 | oranjemund
# Processing Record 12 of Set 8 | skjervoy
# Processing Record 13 of Set 8 | mkushi
# Processing Record 14 of Set 8 | saldanha
# Processing Record 15 of Set 8 | erdenet
# Processing Record 16 of Set 8 | ozieri
# Processing Record 17 of Set 8 | selma
# Processing Record 18 of Set 8 | parkes
# Processing Record 19 of Set 8 | mount isa
# Processing Record 20 of Set 8 | lima duarte
# Processing Record 21 of Set 8 | severobaykalsk
# Processing Record 22 of Set 8 | haapiti
# Processing Record 23 of Set 8 | goma
# Processing Record 24 of Set 8 | novobirilyussy
# Processing Record 25 of Set 8 | oranjestad
# Processing Record 26 of Set 8 | virginia beach
# Processing Record 27 of Set 8 | yuzhno-kurilsk
# Processing Record 28 of Set 8 | cururupu
# Processing Record 29 of Set 8 | shimodate
# Processing Record 30 of Set 8 | miguel alves
# Processing Record 31 of Set 8 | presidencia roque saenz pena
# Processing Record 32 of Set 8 | inongo
# Processing Record 33 of Set 8 | gastonia
# Processing Record 34 of Set 8 | saint-pierre
# Processing Record 35 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 36 of Set 8 | saint-ambroise
# Processing Record 37 of Set 8 | coquimbo
# Processing Record 38 of Set 8 | kahului
# Processing Record 39 of Set 8 | kirensk
# Processing Record 40 of Set 8 | labuhan
# Processing Record 41 of Set 8 | tiznit
# Processing Record 42 of Set 8 | camacha
# Processing Record 43 of Set 8 | salalah
# Processing Record 44 of Set 8 | arman
# Processing Record 45 of Set 8 | naqadeh
# Processing Record 46 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 47 of Set 8 | aleksandrov gay
# Processing Record 48 of Set 8 | koumac
# Processing Record 49 of Set 8 | kemijarvi
# Processing Record 50 of Set 8 | georgiyevka
# Processing Record 1 of Set 9 | port blair
# Processing Record 2 of Set 9 | kirakira
# Processing Record 3 of Set 9 | angoram
# Processing Record 4 of Set 9 | hobyo
# Processing Record 5 of Set 9 | carahue
# Processing Record 6 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 9 | ewa beach
# Processing Record 8 of Set 9 | catio
# Processing Record 9 of Set 9 | saint-augustin
# Processing Record 10 of Set 9 | jiuquan
# Processing Record 11 of Set 9 | wajid
# Processing Record 12 of Set 9 | voyvozh
# Processing Record 13 of Set 9 | acarau
# Processing Record 14 of Set 9 | imbituba
# Processing Record 15 of Set 9 | tilichiki
# Processing Record 16 of Set 9 | maragogi
# Processing Record 17 of Set 9 | bemidji
# Processing Record 18 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 9 | mangrol
# Processing Record 20 of Set 9 | svetlogorsk
# Processing Record 21 of Set 9 | codajas
# Processing Record 22 of Set 9 | itarema
# Processing Record 23 of Set 9 | merauke
# Processing Record 24 of Set 9 | melipilla
# Processing Record 25 of Set 9 | kuito
# Processing Record 26 of Set 9 | teknaf
# Processing Record 27 of Set 9 | noumea
# Processing Record 28 of Set 9 | abu kamal
# Processing Record 29 of Set 9 | staryy nadym
# Processing Record 30 of Set 9 | termoli
# Processing Record 31 of Set 9 | iqaluit
# Processing Record 32 of Set 9 | kaduna
# Processing Record 33 of Set 9 | garissa
# Processing Record 34 of Set 9 | ushtobe
# Processing Record 35 of Set 9 | soyo
# Processing Record 36 of Set 9 | baruun-urt
# Processing Record 37 of Set 9 | terrace
# Processing Record 38 of Set 9 | ust-nera
# Processing Record 39 of Set 9 | esperance
# Processing Record 40 of Set 9 | yarada
# Processing Record 41 of Set 9 | kimbe
# Processing Record 42 of Set 9 | franklin
# Processing Record 43 of Set 9 | itapetinga
# Processing Record 44 of Set 9 | belyy
# Processing Record 45 of Set 9 | latehar
# Processing Record 46 of Set 9 | isla mujeres
# Processing Record 47 of Set 9 | socorro
# Processing Record 48 of Set 9 | wyszkow
# Processing Record 49 of Set 9 | ambilobe
# Processing Record 50 of Set 9 | yen bai
# Processing Record 1 of Set 10 | grand gaube
# Processing Record 2 of Set 10 | praia da vitoria
# Processing Record 3 of Set 10 | colesberg
# Processing Record 4 of Set 10 | ampanihy
# Processing Record 5 of Set 10 | beringovskiy
# Processing Record 6 of Set 10 | filadelfia
# Processing Record 7 of Set 10 | leo
# Processing Record 8 of Set 10 | whitefish
# Processing Record 9 of Set 10 | berlevag
# Processing Record 10 of Set 10 | ulladulla
# Processing Record 11 of Set 10 | ilulissat
# Processing Record 12 of Set 10 | guarapari
# Processing Record 13 of Set 10 | gold coast
# Processing Record 14 of Set 10 | iida
# Processing Record 15 of Set 10 | tawzar
# City not found. Skipping...
# Processing Record 16 of Set 10 | bahile
# Processing Record 17 of Set 10 | assemini
# Processing Record 18 of Set 10 | waterfoot
# Processing Record 19 of Set 10 | zhigansk
# Processing Record 20 of Set 10 | isiro
# Processing Record 21 of Set 10 | joensuu
# Processing Record 22 of Set 10 | pacific grove
# Processing Record 23 of Set 10 | paracuru
# Processing Record 24 of Set 10 | axim
# Processing Record 25 of Set 10 | dondo
# Processing Record 26 of Set 10 | sungaipenuh
# Processing Record 27 of Set 10 | anori
# Processing Record 28 of Set 10 | wanning
# Processing Record 29 of Set 10 | saucillo
# Processing Record 30 of Set 10 | sitka
# Processing Record 31 of Set 10 | goderich
# Processing Record 32 of Set 10 | porlamar
# Processing Record 33 of Set 10 | fare
# Processing Record 34 of Set 10 | yumen
# Processing Record 35 of Set 10 | alta floresta
# Processing Record 36 of Set 10 | nizwa
# Processing Record 37 of Set 10 | vestmanna
# Processing Record 38 of Set 10 | jimenez
# Processing Record 39 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 10 | kavaratti
# Processing Record 41 of Set 10 | verkhnyaya inta
# Processing Record 42 of Set 10 | yaan
# Processing Record 43 of Set 10 | doka
# Processing Record 44 of Set 10 | balkhash
# Processing Record 45 of Set 10 | disna
# Processing Record 46 of Set 10 | bolgar
# Processing Record 47 of Set 10 | vuktyl
# Processing Record 48 of Set 10 | rundu
# Processing Record 49 of Set 10 | silifke
# Processing Record 50 of Set 10 | isangel
# Processing Record 1 of Set 11 | monrovia
# Processing Record 2 of Set 11 | gavle
# Processing Record 3 of Set 11 | kamaishi
# Processing Record 4 of Set 11 | alofi
# Processing Record 5 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 11 | matamoros
# Processing Record 7 of Set 11 | yeppoon
# Processing Record 8 of Set 11 | vicuna
# Processing Record 9 of Set 11 | caravelas
# Processing Record 10 of Set 11 | redmond
# Processing Record 11 of Set 11 | mafinga
# Processing Record 12 of Set 11 | syracuse
# Processing Record 13 of Set 11 | baiima
# Processing Record 14 of Set 11 | shubarshi
# Processing Record 15 of Set 11 | taywarah
# Processing Record 16 of Set 11 | kirkenaer
# Processing Record 17 of Set 11 | abu samrah
# Processing Record 18 of Set 11 | natal
# Processing Record 19 of Set 11 | bosaso
# Processing Record 20 of Set 11 | arlit
# Processing Record 21 of Set 11 | san martin de hidalgo
# City not found. Skipping...
# Processing Record 22 of Set 11 | san patricio
# Processing Record 23 of Set 11 | bogorodskoye
# Processing Record 24 of Set 11 | cherepovets
# Processing Record 25 of Set 11 | biltine
# Processing Record 26 of Set 11 | nakhon thai
# Processing Record 27 of Set 11 | kalaleh
# Processing Record 28 of Set 11 | manokwari
# Processing Record 29 of Set 11 | mawlaik
# Processing Record 30 of Set 11 | ust-omchug
# Processing Record 31 of Set 11 | rio grande
# Processing Record 32 of Set 11 | lannion
# Processing Record 33 of Set 11 | kathmandu
# Processing Record 34 of Set 11 | chinu
# Processing Record 35 of Set 11 | bayangol
# Processing Record 36 of Set 11 | rustenburg
# Processing Record 37 of Set 11 | half moon bay
# Processing Record 38 of Set 11 | kaitangata
# Processing Record 39 of Set 11 | ejea de los caballeros
# Processing Record 40 of Set 11 | chifeng
# Processing Record 41 of Set 11 | nizhniy tsasuchey
# Processing Record 42 of Set 11 | minab
# Processing Record 43 of Set 11 | kontagora
# Processing Record 44 of Set 11 | mata grande
# Processing Record 45 of Set 11 | casper
# Processing Record 46 of Set 11 | lasa
# Processing Record 47 of Set 11 | nome
# Processing Record 48 of Set 11 | klaksvik
# Processing Record 49 of Set 11 | kalmunai
# Processing Record 50 of Set 11 | san jeronimo
# Processing Record 1 of Set 12 | oktyabrskoye
# Processing Record 2 of Set 12 | nouakchott
# Processing Record 3 of Set 12 | vilyuysk
# Processing Record 4 of Set 12 | bowen
# Processing Record 5 of Set 12 | nhulunbuy
# Processing Record 6 of Set 12 | ghansor
# Processing Record 7 of Set 12 | longhua
# Processing Record 8 of Set 12 | sioux lookout
# Processing Record 9 of Set 12 | ayaviri
# Processing Record 10 of Set 12 | mikuni
# Processing Record 11 of Set 12 | nemuro
# Processing Record 12 of Set 12 | sobolevo
# Processing Record 13 of Set 12 | zeya
# Processing Record 14 of Set 12 | eyl
# Processing Record 15 of Set 12 | mingaora
# Processing Record 16 of Set 12 | sibolga
# Processing Record 17 of Set 12 | broken hill
# Processing Record 18 of Set 12 | novosergiyevka
# Processing Record 19 of Set 12 | liminangcong
# City not found. Skipping...
# Processing Record 20 of Set 12 | martapura
# Processing Record 21 of Set 12 | shangrao
# Processing Record 22 of Set 12 | woodstock
# Processing Record 23 of Set 12 | jaypur
# Processing Record 24 of Set 12 | tatarskaya pishlya
# Processing Record 25 of Set 12 | conde
# Processing Record 26 of Set 12 | hundorp
# Processing Record 27 of Set 12 | cayenne
# Processing Record 28 of Set 12 | puerto ayacucho
# Processing Record 29 of Set 12 | orlik
# Processing Record 30 of Set 12 | tandalti
# Processing Record 31 of Set 12 | lindas
# Processing Record 32 of Set 12 | whitianga
# Processing Record 33 of Set 12 | srednekolymsk
# Processing Record 34 of Set 12 | te anau
# Processing Record 35 of Set 12 | bektemir
# Processing Record 36 of Set 12 | kinkala
# Processing Record 37 of Set 12 | aguilas
# Processing Record 38 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 39 of Set 12 | farah
# Processing Record 40 of Set 12 | jericho
# Processing Record 41 of Set 12 | manzhouli
# Processing Record 42 of Set 12 | sangar
# Processing Record 43 of Set 12 | rognan
# Processing Record 44 of Set 12 | bazarnyy syzgan
# Processing Record 45 of Set 12 | high level
# Processing Record 46 of Set 12 | vila velha
# Processing Record 47 of Set 12 | banbury
# Processing Record 48 of Set 12 | muzaffarabad
# Processing Record 49 of Set 12 | lovozero
# Processing Record 50 of Set 12 | winneba
# Processing Record 1 of Set 13 | aguas formosas
# Processing Record 2 of Set 13 | san ramon
# Processing Record 3 of Set 13 | general roca
# Processing Record 4 of Set 13 | shitkino
# Processing Record 5 of Set 13 | roma
# Processing Record 6 of Set 13 | talavera de la reina
# Processing Record 7 of Set 13 | toamasina
# Processing Record 8 of Set 13 | waingapu
# Processing Record 9 of Set 13 | labuan
# Processing Record 10 of Set 13 | sawakin
# Processing Record 11 of Set 13 | hailar
# Processing Record 12 of Set 13 | salamanca
# Processing Record 13 of Set 13 | kharp
# Processing Record 14 of Set 13 | opuwo
# Processing Record 15 of Set 13 | vanavara
# Processing Record 16 of Set 13 | pedasi
# Processing Record 17 of Set 13 | kano
# Processing Record 18 of Set 13 | zabol
# Processing Record 19 of Set 13 | gayeri
# Processing Record 20 of Set 13 | san gabriel
# Processing Record 21 of Set 13 | dawlatabad
# Processing Record 22 of Set 13 | mananjary
# Processing Record 23 of Set 13 | vila franca do campo
# Processing Record 24 of Set 13 | zyryanka
# Processing Record 25 of Set 13 | les cayes
# Processing Record 26 of Set 13 | himora
# City not found. Skipping...
# Processing Record 27 of Set 13 | jacqueville
# Processing Record 28 of Set 13 | iguguno
# Processing Record 29 of Set 13 | cuenca
# Processing Record 30 of Set 13 | biscarrosse
# Processing Record 31 of Set 13 | sept-iles
# Processing Record 32 of Set 13 | bengbu
# Processing Record 33 of Set 13 | sinnamary
# Processing Record 34 of Set 13 | hinton
# Processing Record 35 of Set 13 | gorin
# Processing Record 36 of Set 13 | mentougou
# Processing Record 37 of Set 13 | tommot
# Processing Record 38 of Set 13 | lalmohan
# Processing Record 39 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 13 | samarinda
# Processing Record 41 of Set 13 | tupik
# Processing Record 42 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 43 of Set 13 | macas
# Processing Record 44 of Set 13 | nuuk
# Processing Record 45 of Set 13 | nishihara
# Processing Record 46 of Set 13 | buchanan
# Processing Record 47 of Set 13 | severnoye
# Processing Record 48 of Set 13 | palaia fokaia
# Processing Record 49 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 50 of Set 13 | soubre
# Processing Record 1 of Set 14 | bubaque
# Processing Record 2 of Set 14 | hay river
# Processing Record 3 of Set 14 | kombissiri
# Processing Record 4 of Set 14 | lazaro cardenas
# Processing Record 5 of Set 14 | auki
# Processing Record 6 of Set 14 | asfi
# Processing Record 7 of Set 14 | cubara
# Processing Record 8 of Set 14 | pavlogradka
# Processing Record 9 of Set 14 | forbes
# Processing Record 10 of Set 14 | la palma
# Processing Record 11 of Set 14 | neutraubling
# Processing Record 12 of Set 14 | general teran
# Processing Record 13 of Set 14 | yueyang
# Processing Record 14 of Set 14 | pangnirtung
# Processing Record 15 of Set 14 | roebourne
# Processing Record 16 of Set 14 | amazar
# Processing Record 17 of Set 14 | nalut
# Processing Record 18 of Set 14 | zanjan
# Processing Record 19 of Set 14 | laurel
# Processing Record 20 of Set 14 | kijang
# Processing Record 21 of Set 14 | vanino
# Processing Record 22 of Set 14 | mocuba
# Processing Record 23 of Set 14 | aksu
# Processing Record 24 of Set 14 | sao filipe
# Processing Record 25 of Set 14 | khatra
# Processing Record 26 of Set 14 | roald
# Processing Record 27 of Set 14 | slavyanka
# Processing Record 28 of Set 14 | santa rosa
# Processing Record 29 of Set 14 | egvekinot
# Processing Record 30 of Set 14 | nizhneudinsk
# Processing Record 31 of Set 14 | port arthur
# Processing Record 32 of Set 14 | hualmay
# Processing Record 33 of Set 14 | pakenham
# Processing Record 34 of Set 14 | champerico
# Processing Record 35 of Set 14 | dolgoprudnyy
# Processing Record 36 of Set 14 | gorkovskoye
# City not found. Skipping...
# Processing Record 37 of Set 14 | jacmel
# Processing Record 38 of Set 14 | norrtalje
# Processing Record 39 of Set 14 | asau
# Processing Record 40 of Set 14 | morant bay
# Processing Record 41 of Set 14 | shache
# Processing Record 42 of Set 14 | janauba
# Processing Record 43 of Set 14 | banjar
# Processing Record 44 of Set 14 | anarcs
# Processing Record 45 of Set 14 | vogar
# Processing Record 46 of Set 14 | walvis bay
# Processing Record 47 of Set 14 | pitea
# Processing Record 48 of Set 14 | vagay
# Processing Record 49 of Set 14 | anisoc
# Processing Record 50 of Set 14 | jijiga
# Processing Record 1 of Set 15 | lethem
# Processing Record 2 of Set 15 | luancheng
# Processing Record 3 of Set 15 | imeni babushkina
# Processing Record 4 of Set 15 | valky
# Processing Record 5 of Set 15 | uyemskiy
# Processing Record 6 of Set 15 | yingkou
# Processing Record 7 of Set 15 | rochegda
# Processing Record 8 of Set 15 | aswan
# Processing Record 9 of Set 15 | lianran
# Processing Record 10 of Set 15 | marfino
# Processing Record 11 of Set 15 | inirida
# Processing Record 12 of Set 15 | vangaindrano
# Processing Record 13 of Set 15 | kitzingen
# Processing Record 14 of Set 15 | atamanskaya
# Processing Record 15 of Set 15 | ahipara
# Processing Record 16 of Set 15 | harper
# Processing Record 17 of Set 15 | riyadh
# Processing Record 18 of Set 15 | kot putli
# City not found. Skipping...
# Processing Record 19 of Set 15 | rabo de peixe
# Processing Record 20 of Set 15 | santiago de compostela
# Processing Record 21 of Set 15 | caohe
# Processing Record 22 of Set 15 | braniewo
# Processing Record 23 of Set 15 | ulkan
# Processing Record 24 of Set 15 | golden
# Processing Record 25 of Set 15 | manta
# Processing Record 26 of Set 15 | paka
# Processing Record 27 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 28 of Set 15 | ouallam
# Processing Record 29 of Set 15 | college
# Processing Record 30 of Set 15 | omsukchan
# Processing Record 31 of Set 15 | pahrump
# Processing Record 32 of Set 15 | bambous virieux
# Processing Record 33 of Set 15 | qui nhon
# Processing Record 34 of Set 15 | stepnyak
# Processing Record 35 of Set 15 | zhuhai
# Processing Record 36 of Set 15 | conceicao da barra
# Processing Record 37 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 38 of Set 15 | fairbanks
# Processing Record 39 of Set 15 | ribas do rio pardo
# Processing Record 40 of Set 15 | gao
# Processing Record 41 of Set 15 | ghanzi
# Processing Record 42 of Set 15 | dabakala
# Processing Record 43 of Set 15 | kindu
# Processing Record 44 of Set 15 | sao joao da barra
# Processing Record 45 of Set 15 | teahupoo
# Processing Record 46 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 47 of Set 15 | gambela
# Processing Record 48 of Set 15 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 49 of Set 15 | damietta
# Processing Record 50 of Set 15 | tambopata
# Processing Record 1 of Set 16 | chadiza
# Processing Record 2 of Set 16 | langxiang
# Processing Record 3 of Set 16 | birao
# Processing Record 4 of Set 16 | kholodnyy
# Processing Record 5 of Set 16 | kununurra
# Processing Record 6 of Set 16 | maple creek
# Processing Record 7 of Set 16 | charters towers
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country        Date      Lat       Lng  Max Temp  Humidity  \
# 0   Port Lincoln      AU  1667869642 -34.7333  135.8667     79.18        41
# 1        Mataura      NZ  1667869642 -46.1927  168.8643     65.48        38
# 2    San Lorenzo      PY  1667869391 -25.3333  -57.5333     74.34        43
# 3   Norman Wells      CA  1667869643  65.2820 -126.8329      3.15        75
# 4         Atagay      RU  1667869644  55.1033   99.3875     22.93        84
# 5       Hermanus      ZA  1667869644 -34.4187   19.2345     59.23        87
# 6  Kazachinskoye      RU  1667869644  57.6953   93.2761     22.28        96
# 7          Vaini      TO  1667869645 -21.2000 -175.2000     75.70        75
# 8   Puerto Ayora      EC  1667869619  -0.7393  -90.3518     67.55        85
# 9         Avarua      CK  1667869646 -21.2078 -159.7750     77.05        65
#
#    Cloudiness  Wind Speed      Description
# 0         100       15.59  overcast clouds
# 1          71        3.87    broken clouds
# 2           0        6.91        clear sky
# 3           8        8.12        clear sky
# 4         100        3.76  overcast clouds
# 5          13        6.91       few clouds
# 6          95        4.12  overcast clouds
# 7          20       12.24       light rain
# 8          91        4.00  overcast clouds
# 9          75        6.91    broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
